# %% [markdown]
# # Aula 1

# %% [markdown]
# ## Modelos AR

# %%
import pandas as pd

# %%
dado_ar1 = pd.read_csv('produto_ar1.csv')

# %%
dado_ar1.head()
# Out:
#    Data      Preco
# 0  0.01  10.000000
# 1  0.02   8.710519
# 2  0.03   9.026865
# 3  0.04  10.134112
# 4  0.05  10.529007

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ar1['Data'], dado_ar1['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(dado_ar1['Preco']);

# %%
plot_pacf(dado_ar1['Preco']);

# %%
dado_ar2 = pd.read_csv('produto_ar2.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ar2['Data'], dado_ar2['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %%
plot_acf(dado_ar2['Preco']);

# %%
plot_pacf(dado_ar2['Preco']);

# %%
dado_ar3 = pd.read_csv('produto_ar3.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ar3['Data'], dado_ar3['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %%
plot_acf(dado_ar3['Preco']);

# %%
plot_pacf(dado_ar3['Preco']);

# %% [markdown]
# ## Ajuste dos modelos AR

# %%
dado_ar1_p1 = dado_ar1[0:500]
dado_ar1_p2 = dado_ar1[500:600]

# %%
import statsmodels.tsa.api as smtsa

# %%
modelo_ar1 = smtsa.ARMA(dado_ar1_p1['Preco'], order=(1, 0)).fit()

# %%
modelo_previsto1 = modelo_ar1.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ar1_p1['Data'],dado_ar1_p1['Preco'])
plt.plot(dado_ar1_p2['Data'],dado_ar1_p2['Preco'])
plt.plot(dado_ar1_p2['Data'], modelo_previsto1,'r.')

# %%
dado_ar3_p1 = dado_ar3[0:500]
dado_ar3_p2 = dado_ar3[500:600]

# %%
modelo_ar3 = smtsa.ARMA(dado_ar3_p1['Preco'], order=(3, 0)).fit()

# %%
modelo_previsto3 = modelo_ar3.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ar3_p2['Data'],dado_ar3_p2['Preco'])
plt.plot(dado_ar3_p2['Data'], modelo_previsto3,'r.')

# %% [markdown]
# # Aula 2

# %% [markdown]
# ## Modelos MA

# %%
dado_ma1 = pd.read_csv('produto_ma1.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma1['Data'],dado_ma1['Preco'])

# %%
plot_acf(dado_ma1['Preco']);

# %%
plot_pacf(dado_ma1['Preco']);

# %%
dado_ma1_p1 = dado_ma1[0:500]
dado_ma1_p2 = dado_ma1[500:600]

# %%
modelo_ma1 = smtsa.ARMA(dado_ma1_p1['Preco'], order=(0, 1)).fit()

# %%
modelo_previsto_ma1 = modelo_ma1.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma1_p2['Data'],dado_ma1_p2['Preco'])
plt.plot(dado_ma1_p2['Data'], modelo_previsto_ma1,'.r')

# %%
dado_ma3 = pd.read_csv('produto_ma3.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma3['Data'],dado_ma3['Preco'])

# %%
plot_acf(dado_ma3['Preco']);

# %%
dado_ma3_p1 = dado_ma3[0:500]
dado_ma3_p2 = dado_ma3[500:600]

# %%
plot_pacf(dado_ma3['Preco']);

# %%
modelo_ma3 = smtsa.ARMA(dado_ma3_p1['Preco'], order=(0, 3)).fit()

# %%
modelo_previsto_ma3 = modelo_ma3.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma3_p2['Data'],dado_ma3_p2['Preco'])
plt.plot(dado_ma3_p2['Data'], modelo_previsto_ma3,'r.')

# %% [markdown]
# ## Modelo ARMA

# %%
dado_arma1 = pd.read_csv('produto_arma1_1.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_arma1['Data'],dado_arma1['Preco'])

# %%
plot_acf(dado_arma1['Preco']);

# %%
plot_pacf(dado_arma1['Preco']);

# %%
dado_arma1_p1 = dado_arma1[0:500]
dado_arma1_p2 = dado_arma1[500:600]

# %%
modelo_arma1 = smtsa.ARMA(dado_arma1_p1['Preco'], order=(1, 1)).fit()

# %%
modelo_previsto_arma1 = modelo_arma1.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_arma1_p2['Data'],dado_arma1_p2['Preco'])
plt.plot(dado_arma1_p2['Data'], modelo_previsto_arma1,'r')

# %% [markdown]
# ## Previsão e estacionariedade

# %%
cresc = pd.read_csv('produto_crescente.csv')

# %%
cresc.head()
# Out:
#    Data  Preco
# 0  1-01  2.660
# 1  1-02  1.459
# 2  1-03  1.831
# 3  1-04  1.193
# 4  1-05  1.803

# %%
plt.figure(figsize=(12,5))
plt.plot(cresc['Data'],cresc['Preco'])
plt.xticks(rotation=70);

# %%
plot_acf(cresc['Preco']);

# %%
plot_pacf(cresc['Preco']);

# %%
cresc.shape
# Out:
# (36, 2)

# %%
cresc_p1 = cresc[:26][:]
cresc_p2 = cresc[26:][:]

# %%
modelo_cresc = smtsa.ARMA(cresc_p1['Preco'].values, order=(1, 2)).fit();

# %%
modelo_previsto_cresc = modelo_cresc.predict(start=26,end=35)

# %%
plt.figure(figsize=(12,5))
plt.plot(cresc_p1['Data'],cresc_p1['Preco'])
plt.plot(cresc_p1['Data'],modelo_cresc.fittedvalues,'.')
plt.plot(cresc_p2['Data'],cresc_p2['Preco'])
plt.plot(cresc_p2['Data'],modelo_previsto_cresc,'r.')
plt.xticks(rotation=70);

# %%
cres_d = cresc['Preco'].diff(1)

# %%
plt.figure(figsize=(10,4))
plt.plot(cresc['Data'],cres_d)
plt.xticks(rotation=70);

# %%
modelo_cresc = smtsa.ARIMA(cresc_p1['Preco'].values, order=(1,1,2)).fit()

# %%
import numpy as np

# %%
modelo_cresc.plot_predict(26,35);
plt.plot(np.linspace(0,9,10),cresc_p2['Preco'])

# %%
from pmdarima import auto_arima

# %%
modelo_busca = auto_arima(cresc_p1['Preco'].values,
    start_p=0, start_q=0, max_p=6, max_q=6,
    d=1, seasonal=False, trace=True,
    error_action='ignore', suppress_warnings=True,
    stepwise = False)
# Out:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=68.674, BIC=71.112, Time=0.082 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=55.489, BIC=59.146, Time=0.277 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=55.616, BIC=60.491, Time=0.226 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=57.534, BIC=63.628, Time=0.180 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=57.274, BIC=64.588, Time=0.241 seconds
# Fit ARIMA(0,1,5)x(0,0,0,0) [intercept=True]; AIC=53.812, BIC=62.344, Time=0.607 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=57.267, BIC=60.924, Time=0.056 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=55.729, BIC=60.604, Time=0.075 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=56.233, BIC=62.327, Time=0.376 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=58.066, BIC=65.379, Time=0.471 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=57.982, BIC=66.515, Time=0.260 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=58.874, BIC=63.750, Time=0.066 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=57.593, BIC=63.687, Time=0.165 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=58.225, BIC=65.538, Time=0.300 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=59.127, BIC=67.659, Time=0.521 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=54.490, BIC=60.585, Time=0.200 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=55.563, BIC=62.876, Time=0.331 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=51.932, BIC=60.464, Time=0.794 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=55.410, BIC=62.723, Time=0.135 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=57.394, BIC=65.926, Time=0.283 seconds
# Fit ARIMA(5,1,0)x(0,0,0,0) [intercept=True]; AIC=57.388, BIC=65.920, Time=0.144 seconds
# Total fit time: 5.806 seconds

# %%
modelo_busca.aic()
# Out:
# 51.93201970298409

# %%
modelo_busca.bic()
# Out:
# 60.464150477061494

# %%
modelo_busca.fit(cresc_p1['Preco'].values)
# Out:
# ARIMA(order=(3, 1, 2), suppress_warnings=True)

# %%
valores_preditos = modelo_busca.predict(n_periods=10)

# %%
plt.plot(cresc_p2['Data'],valores_preditos)
plt.plot(cresc_p2['Data'],cresc_p2['Preco'])

# %%
from pmdarima.arima.utils import nsdiffs

# %%
D = nsdiffs(cresc_p1['Preco'].values, m=2, max_D=12, test='ch')

# %%
modelo_busca2 = auto_arima(cresc_p1['Preco'].values, start_p=0, start_q=0, max_p=6, max_q=6, d=1, D=1,start_Q = 1,start_P = 1,max_Q=4,max_P=4, m=2,seasonal=True,trace=True,error_action='ignore',supress_warnings=True,stepwise=False)
# Out:
# Fit ARIMA(0,1,0)x(0,1,0,2) [intercept=True]; AIC=69.020, BIC=71.291, Time=0.020 seconds
# Fit ARIMA(0,1,0)x(0,1,1,2) [intercept=True]; AIC=64.388, BIC=67.795, Time=0.100 seconds
# Fit ARIMA(0,1,0)x(0,1,2,2) [intercept=True]; AIC=66.172, BIC=70.714, Time=0.093 seconds
# Fit ARIMA(0,1,0)x(0,1,3,2) [intercept=True]; AIC=67.304, BIC=72.982, Time=0.149 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,0)x(0,1,4,2) [intercept=True]; AIC=67.543, BIC=74.356, Time=0.780 seconds
# Fit ARIMA(0,1,0)x(1,1,0,2) [intercept=True]; AIC=64.047, BIC=67.453, Time=0.052 seconds
# Fit ARIMA(0,1,0)x(1,1,1,2) [intercept=True]; AIC=65.928, BIC=70.470, Time=0.083 seconds
# Fit ARIMA(0,1,0)x(1,1,2,2) [intercept=True]; AIC=67.808, BIC=73.486, Time=0.138 seconds
# Fit ARIMA(0,1,0)x(1,1,3,2) [intercept=True]; AIC=68.649, BIC=75.462, Time=0.342 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,0)x(1,1,4,2) [intercept=True]; AIC=69.255, BIC=77.203, Time=0.687 seconds
# Fit ARIMA(0,1,0)x(2,1,0,2) [intercept=True]; AIC=65.976, BIC=70.518, Time=0.065 seconds
# Fit ARIMA(0,1,0)x(2,1,1,2) [intercept=True]; AIC=66.165, BIC=71.843, Time=0.949 seconds
# Fit ARIMA(0,1,0)x(2,1,2,2) [intercept=True]; AIC=69.579, BIC=76.392, Time=0.214 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,0)x(2,1,3,2) [intercept=True]; AIC=65.378, BIC=73.326, Time=0.903 seconds
# Fit ARIMA(0,1,0)x(3,1,0,2) [intercept=True]; AIC=67.881, BIC=73.559, Time=0.098 seconds
# Fit ARIMA(0,1,0)x(3,1,1,2) [intercept=True]; AIC=69.506, BIC=76.319, Time=0.394 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,0)x(3,1,2,2) [intercept=True]; AIC=70.152, BIC=78.101, Time=0.813 seconds
# Fit ARIMA(0,1,0)x(4,1,0,2) [intercept=True]; AIC=67.668, BIC=74.481, Time=0.139 seconds
# Fit ARIMA(0,1,0)x(4,1,1,2) [intercept=True]; AIC=64.217, BIC=72.165, Time=0.587 seconds
# Fit ARIMA(0,1,1)x(0,1,0,2) [intercept=True]; AIC=59.101, BIC=62.507, Time=0.308 seconds
# Fit ARIMA(0,1,1)x(0,1,1,2) [intercept=True]; AIC=52.719, BIC=57.261, Time=0.424 seconds
# Fit ARIMA(0,1,1)x(0,1,2,2) [intercept=True]; AIC=54.003, BIC=59.680, Time=0.485 seconds
# Fit ARIMA(0,1,1)x(0,1,3,2) [intercept=True]; AIC=54.636, BIC=61.449, Time=0.478 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(0,1,4,2) [intercept=True]; AIC=53.656, BIC=61.605, Time=0.859 seconds
# Fit ARIMA(0,1,1)x(1,1,0,2) [intercept=True]; AIC=51.989, BIC=56.531, Time=0.864 seconds
# Fit ARIMA(0,1,1)x(1,1,1,2) [intercept=True]; AIC=53.596, BIC=59.273, Time=0.655 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(1,1,2,2) [intercept=True]; AIC=55.544, BIC=62.357, Time=0.806 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(1,1,3,2) [intercept=True]; AIC=55.615, BIC=63.563, Time=0.862 seconds
# Fit ARIMA(0,1,1)x(2,1,0,2) [intercept=True]; AIC=53.634, BIC=59.312, Time=0.423 seconds
# Fit ARIMA(0,1,1)x(2,1,1,2) [intercept=True]; AIC=51.841, BIC=58.654, Time=0.758 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(2,1,2,2) [intercept=True]; AIC=49.218, BIC=57.167, Time=0.707 seconds
# Fit ARIMA(0,1,1)x(3,1,0,2) [intercept=True]; AIC=55.546, BIC=62.359, Time=0.471 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(3,1,1,2) [intercept=True]; AIC=52.379, BIC=60.327, Time=0.683 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(0,1,1)x(4,1,0,2) [intercept=True]; AIC=51.426, BIC=59.375, Time=0.748 seconds
# Fit ARIMA(1,1,0)x(0,1,0,2) [intercept=True]; AIC=70.146, BIC=73.553, Time=0.037 seconds
# Fit ARIMA(1,1,0)x(0,1,1,2) [intercept=True]; AIC=59.335, BIC=63.877, Time=0.150 secondsC:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#
# Fit ARIMA(1,1,0)x(0,1,2,2) [intercept=True]; AIC=52.908, BIC=58.586, Time=0.504 seconds
# Fit ARIMA(1,1,0)x(0,1,3,2) [intercept=True]; AIC=54.851, BIC=61.664, Time=0.557 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,0)x(0,1,4,2) [intercept=True]; AIC=54.492, BIC=62.440, Time=0.867 seconds
# Fit ARIMA(1,1,0)x(1,1,0,2) [intercept=True]; AIC=59.271, BIC=63.813, Time=0.130 seconds
# Fit ARIMA(1,1,0)x(1,1,1,2) [intercept=True]; AIC=53.989, BIC=59.666, Time=0.563 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,0)x(1,1,2,2) [intercept=True]; AIC=54.805, BIC=61.618, Time=0.846 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,0)x(1,1,3,2) [intercept=True]; AIC=56.594, BIC=64.542, Time=0.787 seconds
# Fit ARIMA(1,1,0)x(2,1,0,2) [intercept=True]; AIC=57.090, BIC=62.768, Time=0.132 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,0)x(2,1,1,2) [intercept=True]; AIC=55.591, BIC=62.404, Time=1.027 seconds
# Fit ARIMA(1,1,0)x(2,1,2,2) [intercept=True]; AIC=53.842, BIC=61.790, Time=0.552 seconds
# Fit ARIMA(1,1,0)x(3,1,0,2) [intercept=True]; AIC=58.984, BIC=65.797, Time=0.161 seconds
# Fit ARIMA(1,1,0)x(3,1,1,2) [intercept=True]; AIC=57.545, BIC=65.493, Time=0.569 seconds
# Fit ARIMA(1,1,0)x(4,1,0,2) [intercept=True]; AIC=49.573, BIC=57.521, Time=0.415 seconds
# Fit ARIMA(1,1,1)x(0,1,0,2) [intercept=True]; AIC=61.053, BIC=65.595, Time=0.318 seconds
# Fit ARIMA(1,1,1)x(0,1,1,2) [intercept=True]; AIC=54.292, BIC=59.969, Time=0.450 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,1)x(0,1,2,2) [intercept=True]; AIC=55.364, BIC=62.177, Time=0.500 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,1)x(0,1,3,2) [intercept=True]; AIC=55.404, BIC=63.352, Time=0.677 seconds
# Fit ARIMA(1,1,1)x(1,1,0,2) [intercept=True]; AIC=53.662, BIC=59.339, Time=0.683 seconds
# Fit ARIMA(1,1,1)x(1,1,1,2) [intercept=True]; AIC=54.930, BIC=61.743, Time=0.900 seconds
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Fit ARIMA(1,1,1)x(1,1,2,2) [intercept=True]; AIC=56.849, BIC=64.798, Time=0.778 seconds
# Fit ARIMA(1,1,1)x(2,1,0,2) [intercept=True]; AIC=55.037, BIC=61.850, Time=0.961 seconds
# Fit ARIMA(1,1,1)x(2,1,1,2) [intercept=True]; AIC=52.406, BIC=60.354, Time=0.615 seconds
# Fit ARIMA(1,1,1)x(3,1,0,2) [intercept=True]; AIC=56.812, BIC=64.760, Time=0.528 seconds
# Total fit time: 29.900 seconds

# %%
modelo_busca.aic()
# Out:
# 51.93201970298409

# %%
modelo_busca2.aic()
# Out:
# 49.21837963144796

# %%
modelo_busca2.fit(cresc_p1['Preco'].values)
# Out:
# C:\Users\manci\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(order=(0, 1, 1), seasonal_order=(2, 1, 2, 2))

# %%
valores_preditos2 = modelo_busca2.predict(n_periods=10)

# %%
plt.plot(valores_preditos2)
plt.plot(np.linspace(0,9,10),cresc_p2['Preco'])

# %%
from pmdarima.datasets import load_lynx

# %%
dado_lynx = load_lynx()

# %%
dado_lynx.shape
# Out:
# (114,)

# %%
from pmdarima import model_selection

# %%
treino, teste = model_selection.train_test_split(dado_lynx, train_size=100)

# %%
teste1 = teste[:10]
teste2 = teste[10:]

# %%
modelo_arima = auto_arima(treino, start_p=1, start_q=1, d=0, max_p=5, max_q=5, supress_warnings=True, stepwise=True, error_action='ignore')

# %%
previsoes = modelo_arima.predict(n_periods=teste1.shape[0])

# %%
plt.plot(np.arange(0,treino.shape[0]),treino)
plt.plot(np.arange(treino.shape[0],treino.shape[0]+teste1.shape[0]),teste1)
plt.plot(np.arange(treino.shape[0],treino.shape[0]+teste1.shape[0]),previsoes)

# %%
modelo_arima.update(teste1)
# Out:
# ARIMA(order=(2, 0, 0))

# %%
novas_pred = modelo_arima.predict(n_periods = teste2.shape[0])

# %%
plt.plot(np.arange(0,treino.shape[0]),treino)
plt.plot(np.arange(treino.shape[0],treino.shape[0]+teste1.shape[0]),teste1)
plt.plot(np.arange(treino.shape[0],treino.shape[0]+teste1.shape[0]),previsoes)
plt.plot(np.arange(treino.shape[0]+teste1.shape[0],treino.shape[0]+teste1.shape[0]+teste2.shape[0]),novas_pred)

# %%
import joblib

# %%
joblib.dump(modelo_busca2,'sarima.pkl')
# Out:
# ['sarima.pkl']

# %%
previsao_joblib = joblib.load('sarima.pkl').predict(n_periods=10)

# %%
np.allclose(valores_preditos2,previsao_joblib)
# Out:
# True
